# %% [markdown]
# <a href="https://colab.research.google.com/github/rish1411/EDA/blob/main/22BDS0092.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %%
URL = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Employee%20Attrition.csv"

print("Loaded from:", URL)
# Out:
# Loaded from: https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Employee%20Attrition.csv

# %%
df = pd.read_csv(URL)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # **Exploring** **Dimensions**

# %%
print("Shape (rows, cols):", df.shape)
# Out:
# Shape (rows, cols): (1470, 35)

# %%
print("Number of rows:", df.shape[0])
# Out:
# Number of rows: 1470

# %%
print("Number of columns:", df.shape[1])
# Out:
# Number of columns: 35

# %%
print("Column names:", df.columns.tolist())
# Out:
# Column names: ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# ...

# %%
print("Size (cells):", df.size)
# Out:
# Size (cells): 51450

# %%
print("\nInfo:")
df.info()
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %% [markdown]
# # **Summary** **statistics**

# %%
print("Summary statistics (numeric):")
print(df.describe())
# Out:
# Summary statistics (numeric):
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
print("\nUnique values per column:")
print(df.nunique())
# Out:
# Unique values per column:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# ...

# %%
print("\nSum of numeric columns:")
print(df.sum(numeric_only=True))
# Out:
# Sum of numeric columns:
# Age                            54278
# DailyRate                    1179654
# DistanceFromHome               13513
# Education                       4282
# EmployeeCount                   1470
# EmployeeNumber               1506552
# EnvironmentSatisfaction         4001
# HourlyRate                     96860
# JobInvolvement                  4013
# JobLevel                        3034
# JobSatisfaction                 4011
# MonthlyIncome                9559309
# MonthlyRate                 21040262
# NumCompaniesWorked              3959
# PercentSalaryHike              22358
# PerformanceRating               4636
# RelationshipSatisfaction        3987
# StandardHours                 117600
# StockOptionLevel                1167
# TotalWorkingYears              16581
# TrainingTimesLastYear           4115
# WorkLifeBalance                 4059
# YearsAtCompany                 10302
# YearsInCurrentRole              6217
# ...

# %%
print("\nMean of numeric columns:")
print(df.mean(numeric_only=True))
# Out:
# Mean of numeric columns:
# Age                            36.923810
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1024.865306
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyIncome                6502.931293
# MonthlyRate                 14313.103401
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.209524
# PerformanceRating               3.153741
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# ...

# %%
print("\nMedian of numeric columns:")
print(df.median(numeric_only=True))
# Out:
# Median of numeric columns:
# Age                            36.0
# DailyRate                     802.0
# DistanceFromHome                7.0
# Education                       3.0
# EmployeeCount                   1.0
# EmployeeNumber               1020.5
# EnvironmentSatisfaction         3.0
# HourlyRate                     66.0
# JobInvolvement                  3.0
# JobLevel                        2.0
# JobSatisfaction                 3.0
# MonthlyIncome                4919.0
# MonthlyRate                 14235.5
# NumCompaniesWorked              2.0
# PercentSalaryHike              14.0
# PerformanceRating               3.0
# RelationshipSatisfaction        3.0
# StandardHours                  80.0
# StockOptionLevel                1.0
# TotalWorkingYears              10.0
# TrainingTimesLastYear           3.0
# WorkLifeBalance                 3.0
# YearsAtCompany                  5.0
# YearsInCurrentRole              3.0
# YearsSinceLastPromotion         1.0
# ...

# %%
print("\nMost frequent values (modes):")
print(df.mode().iloc[0])
# Out:
# Most frequent values (modes):
# Age                                           35.0
# Attrition                                       No
# BusinessTravel                       Travel_Rarely
# DailyRate                                    691.0
# Department                  Research & Development
# DistanceFromHome                               2.0
# Education                                      3.0
# EducationField                       Life Sciences
# EmployeeCount                                  1.0
# EmployeeNumber                                   1
# EnvironmentSatisfaction                        3.0
# Gender                                        Male
# HourlyRate                                    66.0
# JobInvolvement                                 3.0
# JobLevel                                       1.0
# JobRole                            Sales Executive
# JobSatisfaction                                4.0
# MaritalStatus                              Married
# ...

# %% [markdown]
# # **Data** **Handling**

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %%
print("\nPercentage of missing values:")
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Percentage of missing values:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# ...

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"\nValue counts for '{col}':")
    print(df[col].value_counts())
# Out:
# Value counts for 'Attrition':
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
# Value counts for 'BusinessTravel':
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
# Value counts for 'Department':
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
# Value counts for 'EducationField':
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
# Value counts for 'Gender':
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
# Value counts for 'JobRole':
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# ...

# %%
print("\nNumber of duplicate rows:", df.duplicated().sum())
if df.duplicated().sum() > 0:
    print(df[df.duplicated()])
# Out:
# Number of duplicate rows: 0

# %%
print("\nConstant columns:")
print([col for col in df.columns if df[col].nunique() == 1])
# Out:
# Constant columns:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %% [markdown]
# # **Data** **Cleaning**

# %%
df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)
# there are no duplicates in my given dataset.
# Out:
# Shape after removing duplicates: (1470, 35)

# %%
for col in df.columns:
    if df[col].nunique() == 1:
        df.drop(columns=col, inplace=True)
print("Shape after removing constant columns:", df.shape)
# Out:
# Shape after removing constant columns: (1470, 32)

# %%
num_cols = df.select_dtypes(include=['number']).columns

df[num_cols] = df[num_cols].fillna(df[num_cols].median())
print("Filled missing values for numeric columns with median")

obj_cols = df.select_dtypes(include=['object']).columns
df[obj_cols] = df[obj_cols].apply(lambda col: col.fillna(col.mode()[0]))
print("Filled missing values for categorical columns with mode")
# Out:
# Filled missing values for numeric columns with median
# Filled missing values for categorical columns with mode

# %%
print("\nMissing values after cleaning:")
print(df.isnull().sum())

#there are no missing values in my given data
# Out:
# Missing values after cleaning:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# ...

# %% [markdown]
# # **UNIVARIATE** **ANALYSIS**
# 1. HISTOGRAM
# 2. BOX PLOT
# 3. FACET GRID
# 4. Count Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = df.select_dtypes(exclude=[np.number]).columns.tolist()

# %%
# Histogram for all numeric columns
for col in num_cols:
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Boxplot for numeric columns
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
#FacetGrid
g = sns.FacetGrid(df, col="Attrition")
g.map(plt.hist, "Age", bins=20, edgecolor="black")
g.set_axis_labels("Age", "Count")
g.set_titles(col_template="Attrition = {col_name}")
plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, data=df)
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # **BIVARIATE** **ANALYSIS**
# 1. Scatter plot: Relationship between two numeric variables(DailyRate vs Age, MonthlyIncome vs TotalWorkingYears) and their Correlation
# 2. Example of positive correlation (YearsAtCompany vs YearsWithCurrManager)
# 3. Example of negative correlation (DistanceFromHome vs YearsSinceLastPromotion)
# 4. Boxplot between categorical and numeric variables(Department vs MonthlyIncome, JobRole vs MonthlyIncome, Education vs Age)

# %%
plt.scatter(df["Age"], df["DailyRate"])
plt.title("Scatter Plot for Age vs DailyRate")
plt.xlabel("Age")
plt.ylabel("DailyRate")
plt.show()
print("Correlation (Age vs DailyRate):", np.corrcoef(df["Age"], df["DailyRate"]))
# Out:
# Correlation (Age vs DailyRate): [[1.         0.01066094]
#  [0.01066094 1.        ]]

# %%
plt.scatter(df["TotalWorkingYears"], df["MonthlyIncome"])
plt.title("Scatter Plot for TotalWorkingYears vs MonthlyIncome")
plt.xlabel("TotalWorkingYears")
plt.ylabel("MonthlyIncome")
plt.show()

print("Correlation (TotalWorkingYears vs MonthlyIncome):",
      np.corrcoef(df["TotalWorkingYears"], df["MonthlyIncome"]))
# Out:
# Correlation (TotalWorkingYears vs MonthlyIncome): [[1.         0.77289325]
#  [0.77289325 1.        ]]

# %%
print("correlation example:",
      np.corrcoef(df["YearsAtCompany"], df["YearsWithCurrManager"]))
# Out:
# correlation example: [[1.         0.76921243]
#  [0.76921243 1.        ]]

# %%
print("Another correlation example:",
      np.corrcoef(df["DistanceFromHome"], df["YearsSinceLastPromotion"]))
# Out:
# Another correlation example: [[1.         0.01002884]
#  [0.01002884 1.        ]]

# %%
sns.boxplot(x="Department", y="MonthlyIncome", data=df)
plt.title("MonthlyIncome by Department")
plt.show()

# %%
sns.boxplot(x="JobRole", y="MonthlyIncome", data=df)
plt.title("MonthlyIncome by JobRole")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x="Education", y="Age", data=df)
plt.title("Age by Education Level")
plt.show()

# %% [markdown]
# # **Multivariate** **Analysis**
# 1. Pair Plot with Regression Lines
# 2. Pair Plot with Hue, Labels, and Density Diagonals
# 3. Pearson Correlation Between Two Variables
# 4. Correlation Matrix for All Numeric Columns
# 5. Heatmap of the Correlation Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(df, vars=['Age', 'MonthlyIncome', 'TotalWorkingYears'], kind="reg")
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, height=2, vars=['Age', 'MonthlyIncome', 'YearsAtCompany'], hue="Attrition")
plt.show()

# %%
from scipy import stats

corr = stats.pearsonr(df["MonthlyIncome"], df["TotalWorkingYears"])
print("p-value:\t", corr[1])
print("correlation:\t", corr[0])
# Out:
# p-value:	 2.7293476156909726e-292
# correlation:	 0.7728932462543562

# %%
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# ...

# %%
sns.heatmap(correlation,
            xticklabels=correlation.columns,
            yticklabels=correlation.columns)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## **1D** **ANALYSIS**

# %%
from scipy import stats
from scipy.stats import skew, kurtosis

# Pick a numeric column for demonstration like 'MonthlyIncome'
col = "MonthlyIncome"
x = df[col].values

print("Central Tendency Measures for", col)
print("Arithmetic Mean:", np.mean(x))
weights = df['YearsAtCompany'].replace({0:1}).values
print("Weighted Mean (weights=YearsAtCompany):", np.average(x, weights=weights))
print("Quadratic Mean (RMS):", np.sqrt(np.mean(x**2)))
print("Harmonic Mean:", len(x)/np.sum(1/x))
print("Geometric Mean:", stats.gmean(x))
print("Median:", np.median(x))

def get_mode(arr):
    vals, counts = np.unique(arr, return_counts=True)
    return vals[np.argmax(counts)]
print("Mode:", get_mode(x))

print("\nPosition Measures")
print("Quartiles:", np.quantile(x, [0.25,0.5,0.75]))
print("Deciles:", np.quantile(x, np.linspace(0.1,0.9,9)))
print("Percentiles:", np.quantile(x, np.linspace(0.01,0.99,99))[:10], "...")

print("\nDispersion Measures")
print("Range:", np.max(x)-np.min(x))
print("IQR:", stats.iqr(x))
deciles = np.quantile(x,[0.1,0.9])
print("Interdecile Range:", deciles[1]-deciles[0])
print("Std Dev:", np.std(x, ddof=1))
print("Variance:", np.var(x, ddof=1))
# Out:
# Central Tendency Measures for MonthlyIncome
# Arithmetic Mean: 6502.931292517007
# Weighted Mean (weights=YearsAtCompany): 8598.969940073459
# Quadratic Mean (RMS): 8027.321740945299
# Harmonic Mean: 4229.01785231627
# Geometric Mean: 5179.766220735205
# Median: 4919.0
# Mode: 2342
#
# Position Measures
# Quartiles: [2911. 4919. 8379.]
# Deciles: [ 2317.6  2695.8  3316.9  4228.8  4919.   5743.4  6886.   9860.  13775.6]
# Percentiles: [1382.46 1866.22 2028.07 2070.   2097.9  2143.14 2187.   2241.12 2288.21
#  2317.6 ] ...
#
# Dispersion Measures
# Range: 18990
# IQR: 5468.0
# Interdecile Range: 11458.000000000007
# Std Dev: 4707.956783097994
# Variance: 22164857.07151841

# %%
print("\nShape Measures")
print("Skewness:", skew(x))
print("Kurtosis:", kurtosis(x))
# Out:
# Shape Measures
# Skewness: 1.3684185123330814
# Kurtosis: 0.9977379294765711

# %%
# Frequency distribution
print("\nFrequency Distribution for Department")
print(df['Department'].value_counts())
# Out:
# Frequency Distribution for Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
# Histogram + Frequency Polygon
plt.figure(figsize=(7,4))
plt.hist(x, bins=10, edgecolor='k', alpha=0.6)
plt.plot(sorted(x), np.linspace(0,1,len(x)), color='red')
plt.title("Histogram & Frequency Polygon of MonthlyIncome - 22BDS0092")
plt.xlabel("MonthlyIncome")
plt.ylabel("Frequency")
plt.show()

# %%
print("\nRelative frequency for MonthlyIncome bins:")
print(pd.value_counts(pd.cut(x, bins=5), normalize=True))
# Out:
# Relative frequency for MonthlyIncome bins:
# (990.01, 4807.0]      0.485714
# (4807.0, 8605.0]      0.271429
# (8605.0, 12403.0]     0.112925
# (16201.0, 19999.0]    0.082313
# (12403.0, 16201.0]    0.047619
# Name: proportion, dtype: float64
# /tmp/ipython-input-3862209779.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(pd.cut(x, bins=5), normalize=True))

# %%
# Pie Chart
plt.figure(figsize=(6,6))
df['Department'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Department Distribution - 22BDS0092")
plt.ylabel("")
plt.show()

# %%
# Stacked bar
df['AgeGroup'] = pd.cut(df['Age'], bins=[17,25,35,45,55,65], labels=["18-25","26-35","36-45","46-55","56-65"])
ct = pd.crosstab(df['AgeGroup'], df['Department'])
ct.plot(kind='bar', stacked=True, figsize=(10,5))
plt.title("AgeGroup vs Department - 22BDS0092")
plt.show()

# %%
# Histogram + KDE for Age
plt.figure(figsize=(7,4))
sns.histplot(df['Age'], bins=20, kde=True, color='orange')
plt.title("Distribution of Age - 22BDS0092")
plt.show()

# %%
# Violin plot for MonthlyRate
plt.figure(figsize=(7,4))
sns.violinplot(x=df['MonthlyRate'], color='lightblue')
plt.title("Violin Plot of MonthlyRate - 22BDS0092")
plt.show()

# %%
# Countplot for BusinessTravel
plt.figure(figsize=(7,4))
sns.countplot(x='BusinessTravel', data=df, palette='Set2')
plt.title("BusinessTravel Frequency - 22BDS0092")
plt.show()
# Out:
# /tmp/ipython-input-2561991862.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Density plot for TotalWorkingYears
plt.figure(figsize=(7,4))
sns.kdeplot(df['TotalWorkingYears'], fill=True, color='green')
plt.title("Density of TotalWorkingYears - 22BDS0092")
plt.show()

# %% [markdown]
# ## **2D** **ANALYSIS**

# %%
# Contingency tables
ct = pd.crosstab(df['Attrition'], df['Department'])
print("Contingency Table Attrition vs Department:\n", ct)

print("\nRow profiles:")
print(ct.div(ct.sum(axis=1), axis=0))

print("\nColumn profiles:")
print(ct.div(ct.sum(axis=0), axis=1))
# Out:
# Contingency Table Attrition vs Department:
#  Department  Human Resources  Research & Development  Sales
# Attrition
# No                       51                     828    354
# Yes                      12                     133     92
#
# Row profiles:
# Department  Human Resources  Research & Development     Sales
# Attrition
# No                 0.041363                0.671533  0.287105
# Yes                0.050633                0.561181  0.388186
#
# Column profiles:
# Department  Human Resources  Research & Development     Sales
# Attrition
# No                 0.809524                0.861602  0.793722
# Yes                0.190476                0.138398  0.206278

# %%
chi2, p, dof, ex = stats.chi2_contingency(ct)
print("\nChi-square Attrition x Department:", chi2, "p-value:", p)
# Out:
# Chi-square Attrition x Department: 10.79600732241067 p-value: 0.004525606574479633

# %%
# Scatter plot Age vs MonthlyIncome
plt.figure(figsize=(7,5))
sns.scatterplot(x='Age', y='MonthlyIncome', hue='Attrition', data=df)
plt.title("Age vs MonthlyIncome - 22BDS0092")
plt.show()

# %%
# Boxplot Fare by Department equivalent
plt.figure(figsize=(9,5))
sns.boxplot(x='Department', y='MonthlyIncome', data=df)
plt.title("MonthlyIncome by Department - 22BDS0092")
plt.show()

# %%
# Scatter plot: DailyRate vs HourlyRate
plt.figure(figsize=(7,5))
sns.scatterplot(x='DailyRate', y='HourlyRate', hue='Gender', data=df)
plt.title("DailyRate vs HourlyRate by Gender - 22BDS0092")
plt.show()

# %%
# Boxplot: JobRole vs Age
plt.figure(figsize=(10,5))
sns.boxplot(x='JobRole', y='Age', data=df)
plt.xticks(rotation=45)
plt.title("Age by JobRole - 22BDS0092")
plt.show()

# %%
# Violin plot: Attrition vs YearsAtCompany
plt.figure(figsize=(7,5))
sns.violinplot(x='Attrition', y='YearsAtCompany', data=df, palette="Set1")
plt.title("YearsAtCompany by Attrition - 22BDS0092")
plt.show()
# Out:
# /tmp/ipython-input-132960109.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Heatmap for correlation of selected features
plt.figure(figsize=(8,6))
sns.heatmap(df[['Age','DailyRate','MonthlyIncome','DistanceFromHome','YearsAtCompany']].corr(),
            annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap - 22BDS0092")
plt.show()

# %% [markdown]
# ## **3D** **ANALYSIS**

# %%
import plotly.express as px

fig = px.scatter_3d(df, x='Age', y='MonthlyIncome', z='YearsAtCompany',
                    color='Attrition', title="3D Scatter: Age, MonthlyIncome, YearsAtCompany - 22BDS0092")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Department', y='MonthlyIncome', hue='Attrition', data=df)
plt.title("3D-style Boxplot: Department & Attrition vs MonthlyIncome - 22BDS0092")
plt.show()

# %%
# 3D scatter: Age, DistanceFromHome, YearsAtCompany
fig = px.scatter_3d(df, x='Age', y='DistanceFromHome', z='YearsAtCompany',
                    color='Attrition',
                    title="3D Scatter: Age vs DistanceFromHome vs YearsAtCompany - 22BDS0092")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 3D scatter: MonthlyIncome, PercentSalaryHike, YearsWithCurrManager
fig = px.scatter_3d(df, x='MonthlyIncome', y='PercentSalaryHike', z='YearsWithCurrManager',
                    color='JobLevel',
                    title="3D Scatter: Income, Hike%, ManagerYears by JobLevel - 22BDS0092")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Crosstab Department vs Attrition
ct = pd.crosstab(df['Department'], df['Attrition']).reset_index()

x_vals = []
y_vals = []
z_bottom = []
z_top = []

for i, dept in enumerate(ct['Department']):
    for j, attr in enumerate(['No', 'Yes']):
        x_vals.append(i)              # department index
        y_vals.append(j)              # attrition index
        z_bottom.append(0)
        z_top.append(ct.loc[i, attr]) # count

# Create bars as vertical lines
fig = go.Figure()

for xi, yi, zb, zt in zip(x_vals, y_vals, z_bottom, z_top):
    fig.add_trace(go.Scatter3d(
        x=[xi, xi],
        y=[yi, yi],
        z=[zb, zt],
        mode='lines',
        line=dict(color='blue', width=20),
        showlegend=False
    ))

fig.update_layout(
    scene=dict(
        xaxis=dict(title='Department', tickvals=list(range(len(ct['Department']))), ticktext=ct['Department']),
        yaxis=dict(title='Attrition', tickvals=[0,1], ticktext=['No','Yes']),
        zaxis=dict(title='Count')
    ),
    title="3D Bar Plot: Department vs Attrition - 22BDS0092"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ct2 = pd.crosstab(df['Gender'], df['Attrition']).reset_index()
x_vals, y_vals, z_bottom, z_top = [], [], [], []
for i, g in enumerate(ct2['Gender']):
    for j, attr in enumerate(['No','Yes']):
        x_vals.append(i)
        y_vals.append(j)
        z_bottom.append(0)
        z_top.append(ct2.loc[i, attr])

fig = go.Figure()
for xi, yi, zb, zt in zip(x_vals, y_vals, z_bottom, z_top):
    fig.add_trace(go.Scatter3d(
        x=[xi, xi], y=[yi, yi], z=[zb, zt],
        mode='lines',
        line=dict(color='red', width=20),
        showlegend=False
    ))

fig.update_layout(
    scene=dict(
        xaxis=dict(title='Gender', tickvals=list(range(len(ct2['Gender']))), ticktext=ct2['Gender']),
        yaxis=dict(title='Attrition', tickvals=[0,1], ticktext=['No','Yes']),
        zaxis=dict(title='Count')
    ),
    title="3D Bar Plot: Gender vs Attrition - 22BDS0092"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Clustering**- **KMeans**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X = df[['Age','MonthlyIncome','TotalWorkingYears']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

wcss = []
for k in range(1,11):
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(X_scaled)
    wcss.append(km.inertia_)

plt.figure(figsize=(7,5))
plt.plot(range(1,11), wcss, 'o-')
plt.title("Elbow Method - 22BDS0092")
plt.xlabel("k")
plt.ylabel("WCSS")
plt.show()

k_opt = 3
km = KMeans(n_clusters=k_opt, random_state=42, n_init=20)
df['Cluster'] = km.fit_predict(X_scaled)

plt.figure(figsize=(8,6))
sns.scatterplot(x='Age', y='MonthlyIncome', hue='Cluster', data=df, palette='Set1')
centers = scaler.inverse_transform(km.cluster_centers_)
plt.scatter(centers[:,0], centers[:,1], c='black', marker='X', s=200, alpha=0.6)
plt.title("KMeans Clusters (Age vs MonthlyIncome) - 22BDS0092")
plt.show()

# %%
print("Silhouette Score:", silhouette_score(X_scaled, df['Cluster']))
# Out:
# Silhouette Score: 0.3707752567859403
